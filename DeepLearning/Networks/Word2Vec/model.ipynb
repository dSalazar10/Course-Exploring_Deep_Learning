# %% [markdown]
# # Loading Data

# %%
# read in the extracted text file      
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# # Pre-processing
#
# 1) Relpace punctuation with tokenized words
#
# 2) Split the data by words
#
# 3) Remove words that appear less than six times
#
# 4) Sort the words from least to most frequent
#
# 5) Create an input embedding layer ('the': '0')
#
# 6) Create an output embedding layer ('0': 'the')

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

# %%
# get list of words
words = preprocess(text)
# print some stats about this word data
print("Total words in text: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words in text: 16680599
# Unique words: 63641

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: Two dictionaries, vocab_to_int, int_to_vocab
    """
    word_counts = Counter(words)
    # sorting the words from most to least frequent in text occurrence
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    # create int_to_vocab dictionaries
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# # Subsampling
#
# For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.

# %%
from collections import Counter
import random
import numpy as np

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
# discard some frequent words, according to the subsampling equation
# create a new list of words for training
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = words[start:idx] + words[idx+1:stop+1]
    
    return list(target_words)

def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
int_text = [i for i in range(20)]
x,y = next(get_batches(int_text, batch_size=4, window_size=5))

# %% [markdown]
# # Validation

# %%
def cosine_similarity(embedding, valid_size=16, valid_window=100, device='cpu'):
    """ Returns the cosine similarity of validation words with words in the embedding matrix.
        Here, embedding should be a PyTorch embedding module.
    """
    
    # Here we're calculating the cosine similarity between some random words and 
    # our embedding vectors. With the similarities, we can look at what words are
    # close to our random words.
    
    # sim = (a . b) / |a||b|
    
    embed_vectors = embedding.weight
    
    # magnitude of embedding vectors, |b|
    magnitudes = embed_vectors.pow(2).sum(dim=1).sqrt().unsqueeze(0)
    
    # pick N words from our ranges (0,window) and (1000,1000+window). lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,
                               random.sample(range(1000,1000+valid_window), valid_size//2))
    valid_examples = torch.LongTensor(valid_examples).to(device)
    
    valid_vectors = embedding(valid_examples)
    similarities = torch.mm(valid_vectors, embed_vectors.t())/magnitudes
        
    return valid_examples, similarities

# %% [markdown]
# # Skip Gram Negative Sampling Implementation of Word2Vec Algorithm

# %%
import torch
from torch import nn
import torch.optim as optim

# Custom Loss function
class NegativeSamplingLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input_vectors, output_vectors, noise_vectors):
        
        batch_size, embed_size = input_vectors.shape
        
        # Input vectors should be a batch of column vectors
        input_vectors = input_vectors.view(batch_size, embed_size, 1)
        
        # Output vectors should be a batch of row vectors
        output_vectors = output_vectors.view(batch_size, 1, embed_size)
        
        # bmm = batch matrix multiplication
        # correct log-sigmoid loss
        out_loss = torch.bmm(output_vectors, input_vectors).sigmoid().log()
        out_loss = out_loss.squeeze()
        
        # incorrect log-sigmoid loss
        noise_loss = torch.bmm(noise_vectors.neg(), input_vectors).sigmoid().log()
        noise_loss = noise_loss.squeeze().sum(1)  # sum the losses over the sample of noise vectors

        # negate and sum correct and noisy log-sigmoid losses
        # return average batch loss
        return -(out_loss + noise_loss).mean()

class SkipGramNeg(nn.Module):
    def __init__(self, n_vocab, n_embed, noise_dist=None):
        super().__init__()
        
        self.n_vocab = n_vocab
        self.n_embed = n_embed
        self.noise_dist = noise_dist
        
        # define embedding layers for input and output words
        self.in_embed = nn.Embedding(n_vocab, n_embed)
        self.out_embed = nn.Embedding(n_vocab, n_embed)
        
        # Initialize embedding tables with uniform distribution
        # I believe this helps with convergence
        self.in_embed.weight.data.uniform_(-1, 1)
        self.out_embed.weight.data.uniform_(-1, 1)
        
    def forward_input(self, input_words):
        input_vectors = self.in_embed(input_words)
        return input_vectors
    
    def forward_output(self, output_words):
        output_vectors = self.out_embed(output_words)
        return output_vectors
    
    def forward_noise(self, batch_size, n_samples):
        """ Generate noise vectors with shape (batch_size, n_samples, n_embed)"""
        if self.noise_dist is None:
            # Sample words uniformly
            noise_dist = torch.ones(self.n_vocab)
        else:
            noise_dist = self.noise_dist
            
        # Sample words from our noise distribution
        noise_words = torch.multinomial(noise_dist,
                                        batch_size * n_samples,
                                        replacement=True)
        
        device = "cuda" if model.out_embed.weight.is_cuda else "cpu"
        noise_words = noise_words.to(device)
        
        noise_vectors = self.out_embed(noise_words).view(batch_size, n_samples, self.n_embed)
        
        return noise_vectors

# %% [markdown]
# # Training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Get our noise distribution
# Using word frequencies calculated earlier in the notebook
word_freqs = np.array(sorted(freqs.values(), reverse=True))
unigram_dist = word_freqs/word_freqs.sum()
noise_dist = torch.from_numpy(unigram_dist**(0.75)/np.sum(unigram_dist**(0.75)))

# instantiating the model
embedding_dim = 300
model = SkipGramNeg(len(vocab_to_int), embedding_dim, noise_dist=noise_dist).to(device)

# using the loss that we defined
criterion = NegativeSamplingLoss() 
optimizer = optim.Adam(model.parameters(), lr=0.003)

print_every = 1500
steps = 0
epochs = 5

# train for some number of epochs
for e in range(epochs):
    
    # get our input, target batches
    for input_words, target_words in get_batches(train_words, 512):
        steps += 1
        inputs, targets = torch.LongTensor(input_words), torch.LongTensor(target_words)
        inputs, targets = inputs.to(device), targets.to(device)
        
        # input, output, and noise vectors
        input_vectors = model.forward_input(inputs)
        output_vectors = model.forward_output(targets)
        noise_vectors = model.forward_noise(inputs.shape[0], 5)

        # negative sampling loss
        loss = criterion(input_vectors, output_vectors, noise_vectors)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # loss stats
        if steps % print_every == 0:
            print("Epoch: {}/{}".format(e+1, epochs))
            print("Loss: ", loss.item()) # avg batch loss at this point in training
            valid_examples, valid_similarities = cosine_similarity(model.in_embed, device=device)
            _, closest_idxs = valid_similarities.topk(6)

            valid_examples, closest_idxs = valid_examples.to('cpu'), closest_idxs.to('cpu')
            for ii, valid_idx in enumerate(valid_examples):
                closest_words = [int_to_vocab[idx.item()] for idx in closest_idxs[ii]][1:]
                print(int_to_vocab[valid_idx.item()] + " | " + ', '.join(closest_words))
            print("...\n")
# Out:
# km
# discovered | vanish, ancestry, smilga, sommerfeld, french
# institute | keaton, four, pd, nine, with
# san | milius, hireling, le, agincourt, pharaoh
# universe | thereupon, antioxidant, natural, finally, bulwer
# ...
#
# Epoch: 1/5
# Loss:  4.1010212898254395
# some | a, as, in, and, of
# no | the, an, that, for, a
# seven | one, five, zero, six, nine
# three | two, five, zero, seven, one
# about | zero, as, two, they, are
# more | be, their, as, or, this
# four | nine, one, six, zero, five
# most | are, in, it, of, with
# know | may, a, misses, lifes, imagesize
# brother | dione, as, preferring, charters, ecmascript
# freedom | living, alone, injection, moabite, digraph
# mean | power, lecturer, alphorn, summertime, order
# primarily | passport, electrical, mirror, hence, redemption
# mathematics | uncia, turk, czapski, medford, tries
# lived | had, tombs, sequenced, jarre, bridged
# articles | organically, novel, theorize, their, toe
# ...
#
# Epoch: 1/5
# Loss:  3.615694999694824
# other | as, a, in, of, the
# b | one, nine, four, d, eight
# be | a, that, are, to, can
# five | seven, one, nine, eight, four
# its | the, to, in, of, and
# he | had, his, of, in, one
# as | and, the, other, of, in
# on | to, the, a, of, in
# freedom | their, rule, economic, links, reform
# heavy | concerts, magickal, followed, reintroduced, proboscis
# universe | structure, biblical, different, ichi, circular
# hold | life, universitario, that, countdown, be
# running | petar, reggie, disapproval, stream, pointer
# event | jimi, mummies, colored, confronting, winter
# instance | are, usually, both, used, computations
# question | schafer, tend, although, andalusian, many
# ...
#
# Epoch: 1/5
# Loss:  3.0021934509277344
# will | a, can, that, it, do
# five | seven, zero, eight, one, two
# history | two, john, eight, by, four
# in | the, and, as, of, at
# but | the, of, to, and, in
# war | government, states, republic, after, the
# b | d, eight, american, seven, one
# not | to, of, that, as, do
# engineering | computer, application, computers, software, high
# smith | two, player, john, he, one
# report | government, conduction, forces, created, international
# rise | significant, to, dead, had, out
# recorded | music, live, they, dampen, two
# http | www, com, html, org, online
# prince | duke, leader, th, last, died
# issue | october, to, civil, who, of
# ...
#
# Epoch: 1/5
# Loss:  3.0880727767944336
# not | if, that, or, those, this
# on | the, in, of, and, s
# if | we, not, can, that, function
# th | st, century, nd, rd, city
# which | the, a, is, are, that
# war | army, forces, against, until, peace
# is | the, of, as, a, are
# six | five, zero, two, one, eight
# professional | marketing, appearances, ever, nine, played
# orthodox | churches, jewish, christianity, church, christian
# stage | a, own, well, he, film
# heavy | very, or, fire, temperature, include
# woman | his, her, born, my, she
# ice | temperature, winter, water, edge, moving
# recorded | music, band, album, movie, recording
# dr | singer, seven, actress, isbn, d
# ...
#
# Epoch: 2/5
# Loss:  2.6128716468811035
# were | was, by, their, during, the
# will | to, that, need, so, enough
# they | or, would, to, their, are
# four | eight, one, five, two, zero
# d | b, actress, writer, politician, actor
# used | use, uses, can, and, sometimes
# during | defeat, were, war, when, empire
# as | by, was, this, to, their
# instance | therefore, different, is, can, defined
# construction | largest, trade, development, city, transportation
# mainly | significant, its, such, of, especially
# marriage | child, married, he, religious, christ
# cost | range, speed, system, for, vehicle
# recorded | songs, band, album, recording, his
# alternative | medicine, research, some, particular, complementary
# magazine | movie, album, interview, science, fiction
# ...
#
# Epoch: 2/5
# Loss:  2.811493158340454
# and | of, in, to, on, for
# for | the, to, with, and, of
# are | is, can, or, which, other
# three | eight, one, two, four, seven
# seven | eight, six, three, four, two
# by | the, s, of, in, and
# states | united, state, u, union, constitution
# one | nine, zero, eight, three, four
# know | we, how, i, question, let
# applied | systems, logic, uses, electrical, properties
# issue | self, whether, required, review, value
# taking | with, on, takes, get, when
# egypt | empire, syria, occupied, mediterranean, ethiopia
# scale | physical, study, towards, range, system
# bbc | news, radio, television, broadcast, tv
# something | whether, possible, does, existence, doing
# ...
#
# Epoch: 2/5
# Loss:  2.865931510925293
# years | year, rate, female, income, birth
# other | as, are, in, all, used
# known | see, in, history, name, were
# d | b, nine, l, eight, one
# is | are, defined, the, of, a
# used | or, standard, uses, are, use
# nine | seven, one, eight, two, four
# while | their, but, the, have, were
# experience | so, psychological, mind, mental, that
# active | transfer, widely, development, facilities, proteins
# pope | throne, holy, papal, bishops, rome
# orthodox | churches, church, holy, catholicism, protestant
# channel | television, tv, radio, station, cable
# centre | largest, city, station, center, district
# proposed | theory, approach, scientific, fields, principle
# defense | military, forces, policy, commission, committee
# ...
#
# Epoch: 2/5
# Loss:  2.6906790733337402
# five | one, six, seven, zero, four
# all | are, or, is, be, can
# than | more, these, is, within, length
# not | it, to, that, other, or
# between | the, of, in, to, within
# these | are, very, more, especially, and
# three | two, nine, four, zero, seven
# from | and, the, of, also, by
# something | you, truth, good, your, things
# proposed | theory, ernest, votes, evidence, member
# joseph | john, politician, mathematician, actress, austrian
# gold | silver, grain, nickel, mining, copper
# versions | version, microsoft, windows, interface, graphics
# event | perhaps, events, our, go, ends
# accepted | scholars, christians, present, the, orthodox
# instance | given, are, is, used, like
# ...
#
# Epoch: 2/5
# Loss:  2.635404348373413
# or | is, be, are, can, meaning
# have | to, some, is, are, can
# state | states, constitution, democratic, president, branch
# he | his, went, him, father, wife
# four | three, seven, eight, two, nine
# also | and, as, in, other, is
# first | six, in, nine, eight, seven
# the | in, and, of, east, a
# primarily | specialized, or, common, among, variety
# placed | at, should, often, on, for
# experience | consciousness, perception, she, good, jimi
# behind | the, when, who, them, failure
# older | years, male, performance, earlier, household
# account | sources, text, resolve, accounts, numbers
# taking | any, forward, opponent, score, least
# test | testing, tests, fields, brain, error
# ...
#
# Epoch: 2/5
# Loss:  2.631073474884033
# with | a, the, and, of, up
# during | in, had, was, until, and
# had | was, who, his, during, attempt
# such | other, are, or, for, example
# that | the, a, be, would, is
# is | the, are, which, of, a
# about | in, same, and, they, on
# united | union, states, u, democratic, national
# notes | sound, tone, music, classical, sounds
# bill | president, jonathan, actress, george, one
# hit | players, hits, hitting, season, baseball
# troops | army, forces, war, against, battle
# square | ft, area, kilometers, mi, situated
# powers | monarch, resolve, treaties, force, independent
# scale | scales, instrument, instruments, large, are
# something | because, wrong, do, possible, you
# ...
#
# Epoch: 3/5
# Loss:  2.0665011405944824
# would | if, followed, then, when, not
# th | century, centuries, nd, rd, east
# no | must, to, always, not, if
# up | run, off, on, to, behind
# one | four, seven, three, nine, six
# after | were, in, place, returned, fell
# nine | one, eight, four, two, zero
# b | d, one, footballer, c, physicist
# freedom | organizations, rights, socialist, anarcho, political
# issue | rights, issues, critics, claims, denounced
# police | officers, officer, safety, military, armed
# lived | met, joined, allies, married, died
# applications | systems, devices, components, device, software
# joseph | d, composer, born, peter, writer
# assembly | representatives, legislative, elected, council, elections
# animals | humans, species, insects, animal, human
# ...
#
# Epoch: 3/5
# Loss:  2.4867935180664062
# been | have, and, very, in, most
# the | in, is, and, of, to
# can | or, be, types, are, these
# their | to, in, the, or, a
# during | the, in, and, while, period
# american | nine, association, basketball, list, singer
# new | york, in, college, s, press
# with | to, a, is, are, the
# defense | opponents, defensive, retaliation, guard, forces
# operating | software, unix, interface, microsoft, linux
# frac | equation, cdot, mathbf, sqrt, x
# paris | le, france, du, la, les
# proposed | theory, model, purely, demonstrated, scientists
# smith | john, joseph, author, adam, thomas
# numerous | in, as, about, throughout, also
# discovered | discovery, astronomy, planet, observed, astronomer
# ...
#
# Epoch: 3/5
# Loss:  2.0832130908966064
# would | was, did, when, they, to
# or | is, are, may, be, such
# in | of, and, the, as, a
# two | zero, four, nine, three, six
# for | such, be, as, a, in
# can | is, be, example, make, does
# no | that, have, therefore, they, of
# only | to, the, above, this, as
# marriage | married, daughter, wife, marriages, marry
# applied | theory, or, design, law, theoretical
# shown | patients, usually, shows, duration, that
# square | feet, faces, coordinates, tower, metres
# existence | truth, belief, explain, theory, true
# frac | mathbf, cdot, equation, x, z
# running | run, line, bus, side, rail
# units | unit, density, base, standard, measured
# ...
#
# Epoch: 3/5
# Loss:  2.476837158203125
# its | the, as, of, in, reached
# between | in, the, along, extending, forces
# who | they, not, them, many, when
# over | and, an, zero, in, years
# war | army, allies, against, allied, military
# this | not, is, or, a, to
# often | are, similar, can, or, usually
# he | his, him, himself, whom, wife
# institute | research, university, sciences, medical, universities
# shown | are, or, appear, origin, be
# alternative | used, explanation, difficult, originated, environments
# woman | she, birth, her, female, mother
# recorded | albums, recording, recordings, chart, song
# freedom | freedoms, rights, activists, enforce, liberty
# dr | robert, david, jonathan, jay, actress
# lived | life, himself, his, young, died
# ...
#
# Epoch: 3/5
# Loss:  2.6069045066833496
# this | of, the, it, is, an
# after | during, before, death, in, was
# if | must, will, cannot, be, we
# a | the, in, an, with, to
# its | of, the, a, this, an
# for | and, the, as, in, a
# who | whom, living, mother, of, family
# d | b, laureate, eight, poet, politician
# placed | this, often, give, and, for
# something | things, your, thing, you, so
# gold | silver, copper, bronze, diamonds, tin
# lived | family, living, married, life, his
# nobel | prize, laureate, physicist, physiology, chemist
# institute | university, sciences, research, engineering, graduate
# proposed | proposal, constitution, proposals, disputes, procedure
# file | files, interface, data, internet, format
# ...
#
# Epoch: 3/5
# Loss:  2.619537591934204
# he | his, him, himself, wife, her
# is | are, a, has, other, an
# see | links, list, sites, external, of
# were | against, but, and, had, could
# two | three, five, one, four, eight
# his | he, him, died, wife, brother
# state | states, districts, counties, area, national
# be | can, are, as, to, which
# proposed | proposal, molecular, proposals, conservation, quantitative
# taking | once, immediately, to, after, but
# defense | trial, plan, convicted, armed, abuses
# road | downtown, roads, shopping, mile, street
# recorded | albums, album, recording, band, live
# arts | martial, school, art, schools, colleges
# troops | army, infantry, armed, forces, battalion
# heavy | metal, aircraft, steel, heavily, lighter
# ...
#
# Epoch: 4/5
# Loss:  2.522648811340332
# all | those, to, fact, that, their
# new | york, was, company, and, texas
# s | of, in, nine, and, the
# also | and, as, of, other, the
# used | uses, commonly, use, using, or
# zero | one, two, four, eight, three
# but | not, it, only, have, and
# an | the, a, is, and, for
# animals | animal, humans, insects, mammals, plants
# consists | are, consist, lower, administrative, legislative
# gold | silver, bronze, coins, diamonds, precious
# brother | son, wife, father, him, died
# cost | demand, improved, designed, costs, system
# behind | move, forward, inside, positions, front
# additional | voices, available, use, voice, format
# channel | network, channels, broadcast, cable, radio
# ...
#
# Epoch: 4/5
# Loss:  2.447357416152954
# of | in, the, and, by, a
# war | army, troops, soviet, wars, civil
# over | zero, two, with, the, of
# to | and, is, because, that, a
# some | many, are, various, generally, most
# i | me, let, you, my, know
# many | some, have, not, to, often
# not | to, many, their, however, that
# question | existence, whether, might, questions, know
# engineering | technology, institute, college, science, biomedical
# woman | female, male, she, child, children
# recorded | album, songs, albums, band, recording
# bible | translations, tanakh, testament, hebrew, prophets
# experience | consciousness, sensory, motives, mind, nature
# except | can, these, are, or, do
# quite | others, about, most, lot, generally
# ...
#
# Epoch: 4/5
# Loss:  2.4771175384521484
# and | of, in, the, by, to
# state | of, in, states, legislature, law
# also | the, of, to, and, in
# was | he, had, during, soon, in
# its | of, the, on, with, to
# of | in, and, the, to, a
# other | in, are, the, also, of
# the | a, of, and, to, this
# operations | operation, defense, command, personnel, operational
# engine | engines, piston, combustion, powered, turbine
# heavy | lighter, employed, heavier, fuel, loading
# animals | mammals, animal, birds, humans, insects
# event | events, extinction, time, horizon, moon
# file | files, unix, implementation, windows, microsoft
# ocean | atlantic, pacific, islands, gulf, plateau
# smith | adam, bryan, ted, james, collins
# ...
#
# Epoch: 4/5
# Loss:  2.3369555473327637
# he | his, him, had, himself, was
# that | be, is, it, can, this
# at | in, to, by, were, the
# so | only, indeed, but, be, know
# was | he, were, had, his, the
# be | that, can, is, a, or
# were | by, was, the, had, until
# also | as, is, for, other, in
# articles | com, external, org, website, links
# proposed | referendum, theory, commission, human, proposal
# woman | she, her, female, child, wife
# applied | developments, engineering, properties, pure, theory
# mean | defined, value, sum, arithmetic, frac
# except | are, this, for, any, either
# gold | silver, precious, copper, diamonds, nickel
# accepted | however, recognized, christians, who, sunni
# ...
#
# Epoch: 4/5
# Loss:  2.498217821121216
# for | a, the, s, on, in
# states | united, state, u, nations, confederate
# the | of, in, and, by, a
# time | his, had, early, he, career
# see | references, links, on, article, external
# state | states, united, democratic, legislature, president
# five | three, four, one, two, eight
# so | you, it, same, be, if
# powers | supernatural, marvel, entity, universe, magic
# file | files, format, web, information, interface
# existence | universe, god, supernatural, reality, virtue
# derived | word, descriptive, greek, latin, origin
# recorded | albums, album, recording, recordings, rock
# heavy | metal, thrash, weapons, lighter, low
# woman | female, women, male, child, wife
# pre | origins, modern, origin, commonly, evidence
# ...
#
# Epoch: 4/5
# Loss:  2.3076300621032715
# its | as, the, in, it, most
# if | must, then, can, not, be
# will | can, must, if, you, get
# that | to, it, this, is, be
# but | to, the, a, it, for
# only | of, but, for, first, in
# or | are, is, as, a, of
# can | are, is, be, or, must
# active | mood, movement, present, association, infinitive
# writers | novelists, fiction, literary, literature, poets
# nobel | prize, laureate, recipient, chemist, physicist
# construction | industries, mining, transport, steel, manufacturing
# derived | meaning, origin, word, greek, comes
# stage | film, audiences, actors, screen, on
# orthodox | churches, orthodoxy, church, judaism, congregations
# existence | universe, supernatural, philosophy, philosophical, theory
# ...
#
# Epoch: 5/5
# Loss:  2.0301058292388916
# while | to, had, from, and, of
# all | they, some, and, many, to
# where | delta, y, which, at, form
# been | have, and, was, with, this
# will | therefore, can, if, to, enough
# into | from, to, through, the, and
# some | different, their, many, these, all
# who | had, father, whom, people, been
# brother | son, wife, his, sons, murdered
# operations | operation, ordered, operators, numbers, closure
# proposed | theory, research, proposal, claims, propose
# smith | sidney, john, paul, harris, author
# hit | hitting, hits, singles, band, debut
# older | age, females, males, median, years
# behind | forward, vertical, target, opening, larger
# alternative | medicine, based, therapies, practitioners, hip
# ...
#
# Epoch: 5/5
# Loss:  2.182499647140503
# as | the, and, in, a, of
# their | to, the, they, and, it
# these | some, are, be, can, most
# with | a, the, in, and, as
# his | he, him, her, had, later
# is | a, to, the, this, or
# system | systems, operating, control, use, purposes
# it | is, to, that, a, the
# rise | decline, tide, considerable, fell, largely
# bible | testament, tanakh, prophets, translations, biblical
# pope | pius, papal, innocent, archbishop, bishops
# liberal | party, liberals, conservatives, democrats, election
# accepted | understood, relationship, dispute, adopted, objections
# behind | threw, move, their, win, throwing
# instance | cases, say, some, it, example
# lived | he, years, died, had, after
# ...
#
# Epoch: 5/5
# Loss:  2.4238901138305664
# be | to, that, this, which, can
# during | was, had, after, july, february
# with | and, the, of, in, as
# so | that, it, you, this, they
# when | to, from, be, this, an
# state | states, district, in, legislative, counties
# a | or, in, of, an, is
# the | of, to, this, in, by
# report | agency, news, surveillance, investigations, reports
# gold | silver, precious, platinum, bronze, nickel
# recorded | album, albums, songs, band, recording
# egypt | egyptian, arab, cairo, syria, alexandria
# hit | hits, scored, hitting, rbi, song
# running | run, line, hardware, bus, pcs
# numerous | in, controversy, as, have, many
# alternative | term, scientific, appropriate, an, based
# ...
#
# Epoch: 5/5
# Loss:  2.4108152389526367
# his | he, him, father, whom, was
# had | was, been, were, later, after
# three | four, two, five, six, one
# people | population, living, americans, births, who
# called | are, this, is, or, most
# use | used, still, are, using, uses
# time | been, the, had, it, after
# however | the, not, as, much, been
# bbc | news, television, itv, programmes, broadcast
# square | plaza, feet, dimensional, kilometers, cubic
# know | we, something, like, think, anything
# articles | wikipedia, online, external, org, com
# bible | testament, prophets, biblical, christians, tanakh
# nobel | prize, laureate, chemist, physicist, physiology
# mean | difference, sum, si, value, above
# instance | are, is, given, with, for
# ...
#
# Epoch: 5/5
# Loss:  2.524383306503296
# time | early, later, began, in, had
# only | the, for, and, in, it
# his | he, was, him, s, himself
# six | seven, five, four, one, eight
# a | in, the, and, on, as
# years | age, during, year, over, five
# after | in, during, his, was, before
# can | or, be, example, are, is
# operations | operation, naval, personnel, forces, logistics
# alternative | minor, use, for, com, major
# hold | not, should, orthodoxy, doctrine, if
# running | run, yard, rail, coaching, bus
# bible | testament, prophets, hebrew, tanakh, texts
# primarily | include, also, smaller, use, used
# numerous | many, among, these, and, famous
# quite | cannot, somewhat, does, not, that
# ...
#
# Epoch: 5/5
# Loss:  2.3015077114105225
# see | links, article, references, of, external
# can | be, or, these, are, other
# eight | two, one, four, seven, six
# was | the, but, had, it, later
# known | as, most, and, early, also
# history | see, external, links, timeline, site
# however | has, have, to, not, that
# are | these, is, other, or, has
# nobel | prize, laureate, recipient, chemist, physicist
# construction | industries, mining, closed, built, cement
# joseph | chemist, john, william, jacob, samuel
# active | activity, mood, group, present, forms
# arts | martial, art, student, education, students
# file | files, format, data, formats, interface
# paris | du, france, des, la, les
# bible | prophets, tanakh, testament, revelation, biblical
# ...

# %% [markdown]
# # Visualize Results

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# getting embeddings from the embedding layer of our model, by name
embeddings = model.in_embed.weight.to('cpu').data.numpy()

viz_words = 380
tsne = TSNE()
embed_tsne = tsne.fit_transform(embeddings[:viz_words, :])

fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
